# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
#extract data - fruits
def getFruits(k):
    
    #men k=7
    #women k=10
    
    # "Apples as fruit" 
    i=j=79
    apples = df.ix[i:j,k]

    # "Bananas", "Berries", "Grapes", "Melons", "Oranges Total"
    i=81
    j=85
    bananas = df.ix[i:j,k]

    # "Other citrus fruit", "Stone fruit", "Tropical fruit".
    i=88
    j=90
    others = df.ix[i:j,k]

    applesMatrix = apples.as_matrix()
    bananasMatrix = bananas.as_matrix()
    othersMatrix = others.as_matrix()
    
    allMatrix = np.concatenate((applesMatrix,bananasMatrix,othersMatrix),axis=0)
   
#    print('Values: ' + str(allMatrix))
#    allMatrix = np.reshape(allMatrix, (9, 1))
#    print('Values: ' + str(allMatrix))
    return allMatrix

# %%
#plot - fruits
def plotFruits(gender,caption):
    years = ['94-98','03-04','05-06','07-08']
    yearsNum = np.array([1,2,3,4])
    plt.xticks(yearsNum, years,fontsize=20)
    plt.title('Fruits types over time (' + gender +')',fontsize=20) 
    plt.ylabel('Mean %',fontsize=20) 
    plt.xlabel('Years',fontsize=20)
    plt.plot(yearsNum,finalMatrix[0,0],marker='o',label='Apples as fruit')
    plt.plot(yearsNum,finalMatrix[0,1],marker='o',label='Bananas')
    plt.plot(yearsNum,finalMatrix[0,2],marker='o',label='Berries')
    plt.plot(yearsNum,finalMatrix[0,3],marker='o',label='Grapes')
    plt.plot(yearsNum,finalMatrix[0,4],marker='o',label='Melons')
    plt.plot(yearsNum,finalMatrix[0,5],marker='o',label='Oranges, Total')
    plt.plot(yearsNum,finalMatrix[0,6],marker='o',label='Other citrus fruit')
    plt.plot(yearsNum,finalMatrix[0,7],marker='o',label='Stone fruit')
    plt.plot(yearsNum,finalMatrix[0,8],marker='o',label='Tropical fruit')

    plt.rcParams['figure.figsize'] = (12.0,10.0) 
    plt.annotate(caption, xy=(0.1, -0.2), xycoords='axes fraction')
    plt.rcParams.update({'font.size': 12})

    plt.legend()
    plt.show()

# %%
#extract data - dairy
def getDairy(k):
    
    #men k=7
    #women k=10

    #Fluid milk total"
    i=j=108
    milk = df.ix[i:j,k]

    # "Butter", "Cheese", "Yogurt", "Dairy, Other".
    i=113
    j=116
    others = df.ix[i:j,k]

    milkMatrix = milk.as_matrix()
    othersMatrix = others.as_matrix()

    allMatrix = np.concatenate((milkMatrix,othersMatrix),axis=0)
   
    #print('Values: ' + str(allMatrix))
    #allMatrix = np.reshape(allMatrix, (9, 1))
    #print('Values: ' + str(allMatrix))
    return allMatrix

# %%
#plot - dairy
def plotDairy(gender,caption):
    years = ['94-98','03-04','05-06','07-08']
    yearsNum = np.array([1,2,3,4])
    plt.xticks(yearsNum, years,fontsize=20)
    plt.title('Dairy types over time (' + gender +')',fontsize=20) 
    plt.ylabel('Mean %',fontsize=20) 
    plt.xlabel('Years',fontsize=20)
    plt.plot(yearsNum,finalMatrix[0,0],marker='o',label='Fluid milk total')
    plt.plot(yearsNum,finalMatrix[0,1],marker='o',label='Butter')
    plt.plot(yearsNum,finalMatrix[0,2],marker='o',label='Cheese')
    plt.plot(yearsNum,finalMatrix[0,3],marker='o',label='Yogurt')
    plt.plot(yearsNum,finalMatrix[0,4],marker='o',label='Dairy, other')

    plt.rcParams['figure.figsize'] = (12.0,10.0) 
    plt.annotate(caption, xy=(0.1, -0.2), xycoords='axes fraction')
    plt.rcParams.update({'font.size': 12})
    plt.legend()
    plt.show()

# %%
# fruit-men
k=7

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='94-98 FAH',header=None)
allMatrix0 = getFruits(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='03-04 FAH',header=None)
allMatrix1 = getFruits(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='05-06 FAH',header=None)
allMatrix2 = getFruits(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='07-08 FAH',header=None)
allMatrix3 = getFruits(k);

print('Values - Fruits - Men: ')
print('Values0: ' + str(allMatrix0))
print('Values1: ' + str(allMatrix1))
print('Values2: ' + str(allMatrix2))
print('Values3: ' + str(allMatrix3) + "\n")

#rearrange the matrix
finalMatrix=np.dstack((allMatrix0,allMatrix1,allMatrix2,allMatrix3))
print('Final matrix: ' + str(finalMatrix))
# Out:
# Values - Fruits - Men:
# Values0: [89.18 95.42 84.21 88.79 80.74 85.66 79.82 88.95 74.61]
# Values1: [90.86 94.85 88.57 88.55 79.72 84.46 73.74 94.02 74.58]
# Values2: [89.7 95.59 91.83 93.65 80.85 86 72.95 93.05 76.94]
# Values3: [93.35 93.96 90.7 92.16 84.97 84.16 61.9 95.89 84.68]
#
# Final matrix: [[[89.18 90.86 89.7 93.35]
#   [95.42 94.85 95.59 93.96]
#   [84.21 88.57 91.83 90.7]
#   [88.79 88.55 93.65 92.16]
#   [80.74 79.72 80.85 84.97]
#   [85.66 84.46 86 84.16]
#   [79.82 73.74 72.95 61.9]
#   [88.95 94.02 93.05 95.89]
#   [74.61 74.58 76.94 84.68]]]

# %%
caption = " Figure 1: Fruit type over time (Men). The graph presents consumption of several types \n of fruits in the US over 14 years. Except of 'other citrus fruit', the rates roughly have not \n changed much"
plotFruits('Men',caption)

# %%
#fruit-women
k=10

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='94-98 FAH',header=None)
allMatrix0 = getFruits(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='03-04 FAH',header=None)
allMatrix1 = getFruits(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='05-06 FAH',header=None)
allMatrix2 = getFruits(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='07-08 FAH',header=None)
allMatrix3 = getFruits(k);

print('Values - Fruits - Women: ')
print('Values0: ' + str(allMatrix0))
print('Values1: ' + str(allMatrix1))
print('Values2: ' + str(allMatrix2))
print('Values3: ' + str(allMatrix3) + "\n")

#rearrange the matrix
finalMatrix=np.dstack((allMatrix0,allMatrix1,allMatrix2,allMatrix3))
print('Final matrix: ' + str(finalMatrix))
# Out:
# Values - Fruits - Women:
# Values0: [90.42 94.18 81.73 88.13 84.96 89.77 80.64 89.55 80.4]
# Values1: [91.21 94.57 88.29 90.14 80.99 88.07 69.6 87.94 85.85]
# Values2: [91.5 93.67 90.92 91.33 93.57 88.86 75.13 89.61 76.57]
# Values3: [91.69 94.2 87.99 90.02 85.48 89.35 77.85 94.3 80.72]
#
# Final matrix: [[[90.42 91.21 91.5 91.69]
#   [94.18 94.57 93.67 94.2]
#   [81.73 88.29 90.92 87.99]
#   [88.13 90.14 91.33 90.02]
#   [84.96 80.99 93.57 85.48]
#   [89.77 88.07 88.86 89.35]
#   [80.64 69.6 75.13 77.85]
#   [89.55 87.94 89.61 94.3]
#   [80.4 85.85 76.57 80.72]]]

# %%
caption = " Figure 2: Fruit type over time (Women). The graph presents consumption of several types \n of fruits in the US over 14 years. The rates 'other citrus fruit', 'tropical fruits', and 'melons' \n flactuate compared to the other rates that roughly have not changed much"
plotFruits('Women',caption)

# %%
### dairy-men
k=7

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='94-98 FAH',header=None)
allMatrix0 = getDairy(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='03-04 FAH',header=None)
allMatrix1 = getDairy(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='05-06 FAH',header=None)
allMatrix2 = getDairy(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='07-08 FAH',header=None)
allMatrix3 = getDairy(k);

print('Values - Dairy - Men: ')
print('Values0: ' + str(allMatrix0))
print('Values1: ' + str(allMatrix1))
print('Values2: ' + str(allMatrix2))
print('Values3: ' + str(allMatrix3) + "\n")

#rearrange the matrix
finalMatrix=np.dstack((allMatrix0,allMatrix1,allMatrix2,allMatrix3))
print('Final matrix: ' + str(finalMatrix))
# Out:
# Values - Dairy - Men:
# Values0: [82.57 65.97 57.47 89.68 66.56]
# Values1: [88.83 74 56.3 87.12 73.48]
# Values2: [88.61 77.54 54.56 94.38 69.41]
# Values3: [87.86 74.37 55.2 88.52 69.87]
#
# Final matrix: [[[82.57 88.83 88.61 87.86]
#   [65.97 74 77.54 74.37]
#   [57.47 56.3 54.56 55.2]
#   [89.68 87.12 94.38 88.52]
#   [66.56 73.48 69.41 69.87]]]

# %%
caption = " Figure 3: Dairy types over time (Men). The graph presents consumption of several types \n of dairy products in the US over 14 years. The highest consumption is of 'yogurt' and 'fluid \n milk total', then 'butter' and 'dairy, other', and lastly 'cheese' that isn't popular as the rest"  
plotDairy('Men',caption)

# %%
#dairy-women
k=10

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='94-98 FAH',header=None)
allMatrix0 = getDairy(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='03-04 FAH',header=None)
allMatrix1 = getDairy(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='05-06 FAH',header=None)
allMatrix2 = getDairy(k);

df = pandas.read_excel('CSC599/homework/appendixb.xls', sheetname='07-08 FAH',header=None)
allMatrix3 = getDairy(k);

print('Values - Dairy - Women: ')
print('Values0: ' + str(allMatrix0))
print('Values1: ' + str(allMatrix1))
print('Values2: ' + str(allMatrix2))
print('Values3: ' + str(allMatrix3) + "\n")

#rearrange the matrix
finalMatrix=np.dstack((allMatrix0,allMatrix1,allMatrix2,allMatrix3))
print('Final matrix: ' + str(finalMatrix))
# Out:
# Values - Dairy - Women:
# Values0: [86.69 70.66 62.24 88.22 65.48]
# Values1: [88.92 72.57 59.72 90.57 69.77]
# Values2: [89.69 79.72 63.35 94.82 65.94]
# Values3: [88.38 76.82 62.24 92.56 72.39]
#
# Final matrix: [[[86.69 88.92 89.69 88.38]
#   [70.66 72.57 79.72 76.82]
#   [62.24 59.72 63.35 62.24]
#   [88.22 90.57 94.82 92.56]
#   [65.48 69.77 65.94 72.39]]]

# %%
caption = " Figure 4: Dairy types over time (Women). The graph presents consumption of several types \n of dairy products in the US over 14 years. The results of this graph are similiar to figure 3"  
plotDairy('Women',caption)
